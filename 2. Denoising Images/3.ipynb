# %% [markdown]
# # Compress images using auto-encoder
#
# ```Problem Statement:``` To compress data using auto-encoder in Keras, all you need is to have the same input and output while training the model. Try compressing the CIFAR-10 data set images and arrive at an optimum model. Later use the compressed model to build a classification CNN model and compare the performance with the base CNN model used to classify CIFAR-10 images.
