# %% [markdown]
# # Predective Text Generation using LSTM & GRU
#
# Predict the next five words (i.e. separated by four spaces) of Project Gutenberg EBook of Cactus Forest Drive, Saguaro National Monument using LSTM & GRU.
#
# [File](CactusForestDrive.txt)
