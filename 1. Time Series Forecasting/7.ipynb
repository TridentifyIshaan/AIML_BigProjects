# %% [markdown]
# # Forecasting next month NOCP values using LSTM & GRU
#
# Given the 6 months daily NASDAQ closing price (NOCP) stock data of Google from December 24, 2018 to June 21, 2019. Forecast next month NOCP values using LSTM and GRU with optimal hyperparameters.
#
# [Dataset](GOOGHistoricalNOCP6m.csv)
